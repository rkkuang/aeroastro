# %% [markdown]
# #Aplpy Beginner Tutorial
#
# https://aplpy.readthedocs.io/en/stable/fitsfigure/quickstart.html

# %%
import aplpy
import matplotlib.pyplot as plt

# %%
gc = aplpy.FITSFigure('../aplpytutorial/fits/2MASS_k.fits')
# gc.show_grayscale()
# gc.show_colorscale()
gc.show_colorscale(cmap='gist_heat')
# Out:
# INFO: Auto-setting vmin to  3.347e+02 [aplpy.core]
# INFO: Auto-setting vmax to  2.040e+03 [aplpy.core]

# %%
# plt.figure()
gc.show_rgb('../aplpytutorial/graphics/2MASS_arcsinh_color.png')
gc.tick_labels.set_font(size='small')
